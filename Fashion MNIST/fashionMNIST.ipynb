# %% [markdown]
# ## Fashion MNIST

# %% [markdown]
# ### Import Required Modules

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import numpy as np
import tensorflow as tf
from tensorflow import keras as ks

print(tf.__version__)
# Out:
# 2.5.0

# %% [markdown]
# ### Load Dataset

# %%
(train_images, train_labels), (test_images, test_labels) = ks.datasets.fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 8s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 1s 0us/step

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
len(train_labels)
# Out:
# 60000

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
len(test_labels)
# Out:
# 10000

# %% [markdown]
# ### Data Normalization

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
# train_images

# %% [markdown]
# ### Build Model

# %%
model = ks.models.Sequential()
model.add(ks.layers.Flatten(input_shape=(28, 28), name='Input_layer'))
model.add(ks.layers.Dense(32, activation='relu', name='Hidden_layer'))
model.add(ks.layers.Dense(10, activation='sigmoid', name='Output_layer'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input_layer (Flatten)        (None, 784)               0
# _________________________________________________________________
# Hidden_layer (Dense)         (None, 32)                25120
# _________________________________________________________________
# Output_layer (Dense)         (None, 10)                330
# =================================================================
# Total params: 25,450
# Trainable params: 25,450
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile Model

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Train Model

# %%
model.fit(train_images, train_labels, epochs=10, batch_size=512)
# Out:
# Epoch 1/10
# 118/118 [==============================] - 8s 6ms/step - loss: 0.9620 - accuracy: 0.6900
# Epoch 2/10
# 118/118 [==============================] - 0s 4ms/step - loss: 0.5432 - accuracy: 0.8199
# Epoch 3/10
# 118/118 [==============================] - 1s 5ms/step - loss: 0.4805 - accuracy: 0.8390
# Epoch 4/10
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4495 - accuracy: 0.8477
# Epoch 5/10
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4275 - accuracy: 0.8539
# Epoch 6/10
# 118/118 [==============================] - 1s 4ms/step - loss: 0.4129 - accuracy: 0.8587
# Epoch 7/10
# 118/118 [==============================] - 1s 4ms/step - loss: 0.3972 - accuracy: 0.8624
# Epoch 8/10
# 118/118 [==============================] - 1s 5ms/step - loss: 0.3864 - accuracy: 0.8670
# Epoch 9/10
# 118/118 [==============================] - 1s 6ms/step - loss: 0.3772 - accuracy: 0.8697
# Epoch 10/10
# 118/118 [==============================] - 1s 5ms/step - loss: 0.3700 - accuracy: 0.8719

# %% [markdown]
# ### Model Evaluation

# %%
# training evaluation
train_loss, train_accuracy = model.evaluate(train_images, train_labels)
# Out:
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.3684 - accuracy: 0.8720

# %%
train_accuracy
# Out:
# 0.8720499873161316

# %%
# test evaluation
test_loss, test_accuracy = model.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 1s 1ms/step - loss: 0.4171 - accuracy: 0.8552

# %%
test_accuracy
# Out:
# 0.8551999926567078

# %% [markdown]
# ### Using Deep Neural Network

# %%
dnn_model = ks.models.Sequential()
dnn_model.add(ks.layers.Flatten(input_shape=(28, 28), name='Input_layer'))
dnn_model.add(ks.layers.Dense(128, activation='relu', name='Hidden_layer_1'))
dnn_model.add(ks.layers.Dense(64, activation='relu', name='Hidden_layer_2'))
dnn_model.add(ks.layers.Dense(32, activation='relu', name='Hidden_layer_3'))
dnn_model.add(ks.layers.Dense(10, activation='sigmoid', name='Output_layer'))

# %%
dnn_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input_layer (Flatten)        (None, 784)               0
# _________________________________________________________________
# Hidden_layer_1 (Dense)       (None, 128)               100480
# _________________________________________________________________
# Hidden_layer_2 (Dense)       (None, 64)                8256
# _________________________________________________________________
# Hidden_layer_3 (Dense)       (None, 32)                2080
# _________________________________________________________________
# Output_layer (Dense)         (None, 10)                330
# =================================================================
# Total params: 111,146
# Trainable params: 111,146
# Non-trainable params: 0
# _________________________________________________________________

# %%
dnn_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
dnn_model.fit(train_images, train_labels, epochs=20, batch_size=512)
# Out:
# Epoch 1/20
# 118/118 [==============================] - 18s 78ms/step - loss: 0.7433 - accuracy: 0.7512
# Epoch 2/20
# 118/118 [==============================] - 3s 29ms/step - loss: 0.4390 - accuracy: 0.8451
# Epoch 3/20
# 118/118 [==============================] - 2s 16ms/step - loss: 0.3924 - accuracy: 0.8613
# Epoch 4/20
# 118/118 [==============================] - 2s 13ms/step - loss: 0.3649 - accuracy: 0.8702
# Epoch 5/20
# 118/118 [==============================] - 2s 15ms/step - loss: 0.3437 - accuracy: 0.8759
# Epoch 6/20
# 118/118 [==============================] - 2s 13ms/step - loss: 0.3279 - accuracy: 0.8805
# Epoch 7/20
# 118/118 [==============================] - 2s 16ms/step - loss: 0.3168 - accuracy: 0.8852
# Epoch 8/20
# 118/118 [==============================] - 2s 14ms/step - loss: 0.2983 - accuracy: 0.8909
# Epoch 9/20
# 118/118 [==============================] - 2s 15ms/step - loss: 0.2910 - accuracy: 0.8937
# Epoch 10/20
# 118/118 [==============================] - 2s 13ms/step - loss: 0.2811 - accuracy: 0.8979
# Epoch 11/20
# 118/118 [==============================] - 1s 12ms/step - loss: 0.2752 - accuracy: 0.8995
# Epoch 12/20
# 118/118 [==============================] - 2s 13ms/step - loss: 0.2688 - accuracy: 0.9011
# Epoch 13/20
# 118/118 [==============================] - 2s 14ms/step - loss: 0.2599 - accuracy: 0.9051
# Epoch 14/20
# 118/118 [==============================] - 2s 14ms/step - loss: 0.2515 - accuracy: 0.9072
# Epoch 15/20
# 118/118 [==============================] - 2s 13ms/step - loss: 0.2465 - accuracy: 0.9094
# Epoch 16/20
# 118/118 [==============================] - 1s 13ms/step - loss: 0.2406 - accuracy: 0.9115
# Epoch 17/20
# 118/118 [==============================] - 1s 12ms/step - loss: 0.2385 - accuracy: 0.9113
# Epoch 18/20
# 118/118 [==============================] - 2s 15ms/step - loss: 0.2285 - accuracy: 0.9153
# Epoch 19/20
# 118/118 [==============================] - 2s 14ms/step - loss: 0.2250 - accuracy: 0.9161
# Epoch 20/20
# 118/118 [==============================] - 2s 13ms/step - loss: 0.2218 - accuracy: 0.9180

# %%
# training evaluation
train_loss, train_accuracy = dnn_model.evaluate(train_images, train_labels)
# Out:
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2032 - accuracy: 0.9258

# %%
train_accuracy
# Out:
# 0.9258166551589966

# %%
# test evaluation
test_loss, test_accuracy = dnn_model.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3273 - accuracy: 0.8879: 2s

# %%
test_accuracy
# Out:
# 0.8878999948501587
