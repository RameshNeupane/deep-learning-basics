# %% [markdown]
# ## Fashion MNIST

# %% [markdown]
# ### Import Required Modules

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import numpy as np
import tensorflow as tf

print(tf.__version__)
# Out:
# 2.5.0

# %% [markdown]
# ### Load Dataset

# %%
mnist_fashion = tf.keras.datasets.fashion_mnist

# %%
(train_images, train_labels), (test_images, test_labels) = mnist_fashion.load_data()

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %% [markdown]
# ### Normalize Train and Test Data

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %% [markdown]
# ### Reshape Input into 28 * 28 * 1

# %%
train_images = train_images.reshape((60000, 28, 28, 1))
test_images = test_images.reshape((10000, 28, 28, 1))

# %%
train_images.shape
# Out:
# (60000, 28, 28, 1)

# %%
test_images.shape
# Out:
# (10000, 28, 28, 1)

# %% [markdown]
# ### Create Model

# %% [markdown]
# #### First Layer - Convolutional Layer with relu

# %%
cnn_model = tf.keras.models.Sequential()
cnn_model.add(tf.keras.layers.Conv2D(50, (3, 3), activation='relu', input_shape=(28, 28, 1), name='Conv2D_layer'))

# %% [markdown]
# #### Second Layer - Pooling Layer

# %%
cnn_model.add(tf.keras.layers.MaxPooling2D((2, 2), name='MaxPooling2D_layer'))

# %% [markdown]
# #### Third Layer - Fully Connected Layer

# %%
cnn_model.add(tf.keras.layers.Flatten(name='Flatten'))
cnn_model.add(tf.keras.layers.Dense(50, activation='relu', name='Hidden_layer'))
cnn_model.add(tf.keras.layers.Dense(10, activation='softmax', name='Output_layer'))

# %%
cnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Conv2D_layer (Conv2D)        (None, 26, 26, 50)        500
# _________________________________________________________________
# MaxPooling2D_layer (MaxPooli (None, 13, 13, 50)        0
# _________________________________________________________________
# Flatten (Flatten)            (None, 8450)              0
# _________________________________________________________________
# Hidden_layer (Dense)         (None, 50)                422550
# _________________________________________________________________
# Output_layer (Dense)         (None, 10)                510
# =================================================================
# Total params: 423,560
# Trainable params: 423,560
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Model Optimization

# %%
cnn_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Model Training

# %%
cnn_model.fit(train_images, train_labels, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 47s 20ms/step - loss: 0.4175 - accuracy: 0.8523
# Epoch 2/10
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.2797 - accuracy: 0.8996
# Epoch 3/10
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.2367 - accuracy: 0.9139
# Epoch 4/10
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.2050 - accuracy: 0.9247
# Epoch 5/10
# 1875/1875 [==============================] - 38s 20ms/step - loss: 0.1800 - accuracy: 0.9344
# Epoch 6/10
# 1875/1875 [==============================] - 38s 20ms/step - loss: 0.1570 - accuracy: 0.9424
# Epoch 7/10
# 1875/1875 [==============================] - 38s 20ms/step - loss: 0.1386 - accuracy: 0.9484
# Epoch 8/10
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.1219 - accuracy: 0.9553
# Epoch 9/10
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.1066 - accuracy: 0.9609
# Epoch 10/10
# 1875/1875 [==============================] - 39s 21ms/step - loss: 0.0942 - accuracy: 0.9654

# %% [markdown]
# ### Model Evaluation

# %%
# training evaluation
train_loss, train_accuracy = cnn_model.evaluate(train_images, train_labels)
# Out:
# 1875/1875 [==============================] - 16s 6ms/step - loss: 0.0810 - accuracy: 0.9708

# %%
# test evaluation
test_loss, test_accuracy = cnn_model.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 3s 7ms/step - loss: 0.3040 - accuracy: 0.9094
